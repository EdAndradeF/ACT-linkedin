# %%
import matplotlib.pyplot as pt
import bs4 as bs
import urllib.request
import nltk
import spacy

# %%
jason = pd.read_json('./data/data.json')

# %%
df = pd.read_csv('./data/vagas_tratas_03-06-22.csv', sep='^')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              122 non-null    int64
#  1   id                      122 non-null    int64
#  2   titulo                  122 non-null    object
#  3   empresa                 122 non-null    object
#  4   local                   122 non-null    object
#  5   local_trabalho          122 non-null    int64
#  6   recrutador              65 non-null     object
#  7   aceita_inscricao        102 non-null    object
#  8   descricao               122 non-null    object
#  9   candidatos              122 non-null    int64
#  10  data_publicacao         18 non-null     object
#  11  aberta                  122 non-null    int64
#  12  servico                 122 non-null    object
#  13  tipo_contratacao        67 non-null     float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0          id                        titulo  \
# 0           0  3101701349            DATA ANALYST PLENO
# 1           1  3100401639                   Analista BI
# 2           2  3102104363          Analista de Power BI
# 3           3  3100056434  Business Data Analyst Senior
# 4           4  3094190057                Analista de BI
#
#                  empresa                           local  local_trabalho  \
# 0           Confidencial                          Brasil               2
# 1  PARLA! Contact Center  Carapicuíba, São Paulo, Brasil               1
# 2                Special      Barueri, São Paulo, Brasil               3
# 3         Remessa Online               São Paulo, Brasil               2
# 4          Grupo Nexxees               São Paulo, Brasil               1
#
#                   recrutador              aceita_inscricao  \
# 0       Geizibete Ribeiro 2°  Não aceita mais candidaturas
# 1             Viviane Pontes  Não aceita mais candidaturas
# ...
